# %%
#Punto 1 a)
import numpy as np
import math as m
import matplotlib.pyplot as plt

def funcion(x):
    return(x**(-1)-np.tan(x))
x = np.linspace(0.5, np.pi/2.1,50)

plt.figure(2, (10,6), 100, 'y', 'g')
#y=0*x
plt.plot(x,funcion(x))
plt.plot(x,y)



plt.show()

# %%
#regula falsi
import numpy as np
import math as m
import matplotlib.pyplot as plt

def f(x):
    return x**3
iterator=1
a=1
b=2
maximo=25
eps=0.001
x = b - f(b)*(b-a) / (f(b)-f(a)) 

while (iterator <= maximo and (m.fabs(f(x))> eps)):
    iterator=iterator+1
    if (f(a)*f(x))>0:
        a = x
    else :
        b = x
    x = b - f(b)*( b - a) / (f(b) - f(a)) 
if iterator > maximo :
    print("No converge en", max)
else:
    print("Raiz = " , x) 

print(f(0.86))
# Out:
# No converge en 25
# 0.636056

# %%
#1e
import numpy as np
import math as m
import matplotlib.pyplot as plt

def funcion(x):
    return(x**(-1)-np.tan(x))
def regulaFalsi(a,b,eps,f,maximo):
    iterator=1
    x = b - f(b)*(b-a) / (f(b)-f(a)) 

    while (iterator <= maximo and (m.fabs(f(x))> eps)):
        iterator=iterator+1
        if (f(a)*f(x))>0:
            a = x
        else :
            b = x
        x = b - f(b)*( b - a) / (f(b) - f(a)) 
    if iterator > maximo :
        print("No converge en", maximo,"iteraciones")
    else:
        print("Raiz = " , x, iterator) 


def secante(a,b,eps,f,maximo):
    iterator=0
    x_ant=a
    x=b
    x_sig= x - f(x)*(x- x_ant) / (f(x)-f(x_ant))
    
    while (iterator <= maximo and (m.fabs(x_sig-x)> eps)):   
        x_ant=x
        x=x_sig
        x_sig= x - (f(x)*(x- x_ant)) / (f(x)-f(x_ant))
        iterator=iterator+1
        
    if iterator > maximo :
        print("No converge en", maximo)
    else:
        print("Raiz = " , x,iterator) 
    
    
regulaFalsi(0.5, np.pi/2.1,0.001,funcion,100)
secante(0.5, np.pi/2.1,0.001,funcion,100)
# Out:
# Raiz =  0.86006912464165 33
# Raiz =  0.8603392024288236 4
# -2.078125882953863e-05

# %%
#2a
import numpy as np
import math as m
import matplotlib.pyplot as plt

def funcion(x):
    return(x**2-2*x-3)
x = np.linspace(-4, 4, 50)

plt.figure(2, (10,6), 100, 'y', 'g')
#y=0*x
plt.plot(x,funcion(x))
plt.plot(x,y)



plt.show()

# %%
#Punto fijo

import numpy as np
import math as m

def puntoFijo(func,a,eps, maximo):
    i = 0 # iterador
    b = a+2*eps
     
    while(abs(b-a)>=eps and i<=maximo):
        a = b
        b = func(a)
        i = i+1
   
    if (i>=maximo):
        print("No converge en", maximo)
    else:
        print("Raiz = " , x,iterator)
    
g1=
